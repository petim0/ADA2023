# %% [markdown]
# # Homework 1: A sinister homework
#
# By the end of this homework, we expect you to be able to:
#
# 1. Load data and handle data using pandas;
# 2. Navigate the documentation of Python packages by yourself;
# 3. Filter and tidy up noisy real-world datasets;
# 4. Aggregate your data in different (and hopefully helpful) ways;
# 5. Create meaningful visualizations to analyze the data;
# 6. Communicate your findings in a clear and concise manner
#
#
# ---
#
# ## Important Dates
# - Homework release: Fri 13 Oct 2023
# - **Homework due:** Fri 27 Oct 2023, 23:59
# - Grade release: Mon 06 Nov 2023
#
# ---
#
# ## Some rules
# 1. You are allowed to use any built-in Python library that comes with Anaconda. If you want to use an external library, you may do so, but must justify your choice.
#
# 2. Make sure you use the `data` folder provided in the repository in read-only mode. (Or alternatively, be sure you don’t change any of the files.)
#
# 3. Be sure to provide a concise textual description of your thought process, the assumptions you made, the solution you implemented, and explanations for your answers. A notebook that only has code cells will not suffice.
#
# 4. For questions containing the **/Discuss:/** prefix, answer not with code, but with a textual explanation **(in markdown)**.
#
# 5. Back up any hypotheses and claims with data, since this is an important aspect of the course.
#
# 6. Please write all your comments in **English**, and use meaningful variable names in your code. Your repo should have a single notebook (plus the required data files) in the master/main branch. **If there are multiple notebooks present, we will not grade anything.**
#
# 7. We will **not run your notebook for you!** Rather, we will grade it as is, which means that only the results contained in your evaluated code cells will be considered, and we will not see the results in unevaluated code cells. Thus, be sure to hand in a **fully-run and evaluated notebook**. In order to check whether everything looks as intended, you can check the rendered notebook on the GitHub website once you have pushed your solution there.
#
# 8. In continuation to the previous point, interactive plots, such as those generated using the `plotly` package, should be strictly avoided!
#
# 9. Make sure to print results and/or dataframes that confirm you have properly addressed the task.
#
#
# ---
#
# ##  Context
#
# Congratulations! You have just been hired as a data scientist at "The ByteBlasters", EPFL’s amateur baseball club. The team's manager, Mr. Russo, an eccentric millionaire with an innovative plan to dominate the Swiss baseball league, believes hiring left-handed pitchers (the people who throw the ball) will likely boost the team's performance. Yet, he is concerned about money, as he heard left-handed pitchers have historically earned more!
#
# He tasked you to investigate this "sinister" issue and gave you some openly available data on the birthplace of this beautiful, dynamic sport --- the US.
#
# **About the homework.** This homework consists of four tasks. In Task 0, you will familiarize yourself with the rules of baseball. In Task 1, you will process the data, getting it ready for analysis. In Task 2, you will analyze the data to answer Mr. Russo’s question. Lastly, in Task 3, you will conduct additional analyses that consider the longitudinal nature of the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import YouTubeVideo

# %% [markdown]
# # Task 0 (Ungraded): Baseball 101
#
# **0.1 —** Familiarize yourself with the data; we won't explain the data in-depth in this notebook. Instead, you should take your time to read the readme.txt file inside the data folder. Note that this data is available on [GitHub](https://github.com/chadwickbureau/baseballdatabank).
#
# **0.2 —** Familiarize yourself with basic baseball rules. We will explain everything you need to know, but it will be helpful to get a basic understanding of it. Watching the video below should be enough! (Also available [here](https://www.youtube.com/watch?v=WMA8L5OpuDY).)
#
# A couple of useful things to remember:
# - **Pitchers** (try to) throw the ball
# - **Batters** (try to) hit the ball with the bat
# - **Catchers** (try to) catch the ball.

# %%
YouTubeVideo('WMA8L5OpuDY', width=800, height=300)

# %% [markdown]
# ---
#
# # Task 1 (16 pts): Get to Know Your Data
#
# As a good data scientist, you first load the data and perform some small sanity checks on it.
#
# 1. You are expected to continuously alter your dataframe as you complete the tasks. E.g., if you are asked to filter the data in a specific task, continue using the filtered dataset in the subsequent tasks.
# 2. When we tell you to "print the dataframe," make sure you print it in a way that shows the total number of rows and columns in it (`display(df)` should suffice).
#
# ---

# %% [markdown]
# **1.1 —** Load the `People`, `Salaries`, and `Pitching` dataframes. Then:
# - Filter the `Salaries`, and `Pitching` dataframes to remove all data after the year 2010.
# - For the `Salaries` dataframe drop all duplicate salaries for players in a given year. In other words, if a player (uniquely identified by `PlayerID`) has multiple salaries in a year (`yearID`), keep the first occurence in the dataframe and drop the remaining.
# - Calculate the size of each dataframe.
#
# Make [deep copies](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html) of all dataframes as you filter them.
#
# Hints:
# - 2007 should be included in the data.
# - 2010 should be included in the data.
# - 2011 should not be included in the data.

# %% [markdown]
# **1.2 —** The `throws` column in the `People` dataframe indicates, for each player, whether they throw with the left ("L") or right hand ("R"). Check what values are in the column and drop rows containing any value that is not "L" or "R," again, make a deep copy when you filter the dataframe.
#
# Hint: Remember NaNs!

# %% [markdown]
# **1.3 —** Merge the `People` dataframe with the `Pitching` dataframe. Your merge should populate the pitching data with statistics about the players. Print the resulting dataframe.

# %% [markdown]
# **1.4 —** You realize some of the data for the `throws` column is missing! Estimate the percentage of missing data points per year in that column, and show your estimates in a line plot. Additionally, print what percentage of the data was missing in 1892.

# %% [markdown]
# **1.5 —** Filter the dataset you just merged (hereinafter `Pitching-People`) to just contain data from after 1920 (with 1920 included). Do the same with the `Salaries` dataset. Make deep copies of both dataframes as you filter them.

# %% [markdown]
# **1.6 —**  Merge the `Pitching-People` dataframe with the `Salaries` dataframe. Your merge should populate the `Pitching-People` dataframe with statistics about the pitchers'salaries across the years. Note that the `Salaries` dataframe contains the salary **per year.** Print the resulting dataframe.

# %% [markdown]
# **1.7 —** You realize some of the data for the `salary` column is missing! Estimate the percentage of missing data points per year, and show your estimates in a line plot. Additionally, print what percentage of the data was missing in 2002.

# %% [markdown]
# **1.8 —** Find and print the first and last year for which there exists any salary data. Filter the resulting, merged dataframe to include only data between these two dates. Again make sure you make a deep copy of the dataframe, and print the resulting dataframe.

# %% [markdown]
# ---
#
# # Task 2 (16 pts)
#
# Task 1, was a softball? Huh? For Task 2, you will use a dataset similar to what you obtained at the end of Task 1. This code loads it.

# %%
# PROVIDED CODE

df = pd.read_csv("./data/dataset-task-2.csv")
df.head()
# Out:
#     playerID  yearID  stint teamID lgID  W  L   G  GS  CG  ...  \
# 0  prietar01    1998      1    OAK   AL  0  1   2   2   0  ...
# 1  pooleji02    2000      1    DET   AL  1  0  18   0   0  ...
# 2    leecl02    2007      1    CLE   AL  5  8  20  16   1  ...
# 3  purceda01    2010      1    TOR   AL  1  1  33   0   0  ...
# 4  gundeer01    1992      1    SEA   AL  2  1   9   0   0  ...
#
#         nameGiven  weight  height  bats  throws       debut   finalGame  \
# 0           Ariel   220.0    75.0     R       R  1995-07-02  2001-05-10
# 1   James Richard   190.0    74.0     L       L  1990-06-15  2000-06-01
# 2  Clifton Phifer   205.0    75.0     L       L  2002-09-15  2014-07-31
# 3      David Kent   245.0    77.0     L       L  2008-04-18  2013-09-20
# 4     Eric Andrew   175.0    72.0     R       L  1990-04-11  2000-05-17
#
#     retroID    bbrefID     salary
# 0  priea001  prietar01        NaN
# 1  poolj001  pooleji02   200000.0
# 2  lee-c003    leecl02  3000000.0
# 3  purcd001  purceda01        NaN
# 4  gunde001  gundeer01        NaN
#
# [5 rows x 54 columns]

# %% [markdown]
# Some comments about this dataset:
# - This is a sample of the dataset obtained in Task 1.
# - Even if you  did everything correctly for Task 1, this dataframe would contain a different number of rows --- as it is a sample.
# - This prevent that mistakes made in Task 1 cascade into Tasks 2 and 3.
#
#
# With this data, you will proceed to investigate differences in the salaries and performance of left-handed and right-handed pitchers.
#
# ---

# %% [markdown]
# **2.1 —** Plot the Complementary cumulative distribution function (CCDF) of salary for left-handed and right-handed athletes. Consider data from all years.

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#     playerID  yearID  stint teamID lgID  W  L   G  GS  CG  SHO  SV  IPouts  \
# 0  prietar01    1998      1    OAK   AL  0  1   2   2   0    0   0      25
# 1  pooleji02    2000      1    DET   AL  1  0  18   0   0    0   0      26
# 2    leecl02    2007      1    CLE   AL  5  8  20  16   1    0   0     292
# 3  purceda01    2010      1    TOR   AL  1  1  33   0   0    0   1     102
# 4  gundeer01    1992      1    SEA   AL  2  1   9   0   0    0   0      28
#
#      H  ER  HR  BB  SO  BAOpp    ERA  IBB  WP  HBP  BK    BFP  GF   R   SH  \
# 0   17  11   2   5   8  0.415  11.88  1.0   0  1.0   0   47.0   0  11  0.0
# 1   13   7   4   1   5  0.361   7.27  0.0   0  1.0   0   41.0   1   8  1.0
# 2  112  68  17  36  66  0.284   6.29  1.0   5  7.0   0  443.0   1  73  3.0
# 3   26  14   3  15  32  0.210   3.71  1.0   3  0.0   0  143.0  18  16  2.0
# 4   12   9   1   5   2  0.324   8.68  3.0   0  1.0   2   45.0   4  12  0.0
#
#     SF  GIDP  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  0.0   0.0     1969.0        10.0      22.0         Cuba  La Habana
# 1  2.0   0.0     1966.0         4.0      28.0          USA         NY
# 2  2.0   7.0     1978.0         8.0      30.0          USA         AR
# 3  2.0   0.0     1982.0         4.0      22.0          USA         IL
# 4  2.0   0.0     1966.0         3.0      29.0          USA         OR
#
#      birthCity  deathYear  deathMonth  deathDay deathCountry deathState  \
# 0    La Habana        NaN         NaN       NaN          NaN        NaN
# 1    Rochester        NaN         NaN       NaN          NaN        NaN
# 2       Benton        NaN         NaN       NaN          NaN        NaN
# 3  St. Charles        NaN         NaN       NaN          NaN        NaN
# 4     Portland        NaN         NaN       NaN          NaN        NaN
#
#   deathCity nameFirst   nameLast       nameGiven  weight  height bats throws  \
# 0       NaN     Ariel     Prieto           Ariel   220.0    75.0    R      R
# 1       NaN       Jim      Poole   James Richard   190.0    74.0    L      L
# 2       NaN     Cliff        Lee  Clifton Phifer   205.0    75.0    L      L
# 3       NaN     David     Purcey      David Kent   245.0    77.0    L      L
# 4       NaN      Eric  Gunderson     Eric Andrew   175.0    72.0    R      L
#
#         debut   finalGame   retroID    bbrefID     salary
# 0  1995-07-02  2001-05-10  priea001  prietar01        NaN
# 1  1990-06-15  2000-06-01  poolj001  pooleji02   200000.0
# 2  2002-09-15  2014-07-31  lee-c003    leecl02  3000000.0
# 3  2008-04-18  2013-09-20  purcd001  purceda01        NaN
# 4  1990-04-11  2000-05-17  gunde001  gundeer01        NaN

# %%
#df.columns
#df[["salary","throws"]].head(50)
fig, (ax1,ax2) = plt.subplots(1,2, figsize= (15,8), sharey = True, sharex = True)
ax1.hist(df[df.throws == "R"][["salary"]], bins=20, cumulative=-1, histtype="step")
ax2.hist(df[df.throws == "L"][["salary"]], bins=20, cumulative=-1, histtype="step")

ax1.set_title("CCDF histogram of salaries for right-handed pitchers")
ax2.set_title("CCDF histogram of salaries for left-handed pitchers")

ax1.set_xlabel("Salary")
ax1.set_ylabel("Number of pitchers")

ax2.set_xlabel("Salary")
# Out:
# Text(0.5, 0, 'Salary')

# %% [markdown]
# **2.2 —** /Discuss:/ This plot has an issue which severely limits the amount of information one can draw from it. Describe the issue and propose a solution to address it.

# %%
playerId_and_sal = df.groupby(by="throws")[["playerID", "salary"]].count()
playerId_and_sal.head()
# Out:
#         playerID  salary
# throws
# L           4384    3072
# R          10602    7223

# %%
percentage_missing_sal_left = 1 - playerId_and_sal.loc["L", "salary"] / playerId_and_sal.loc["L", "playerID"]
percentage_missing_sal_right = 1 - playerId_and_sal.loc["R", "salary"] / playerId_and_sal.loc["R", "playerID"]
percentage_missing_sal_global = 1 - df["salary"].count() / df["salary"].shape[0]

print(f"We see that {percentage_missing_sal_left:.2%} of the left-handed players have missing salary values.")
print(f"We see that {percentage_missing_sal_right:.2%} of the right-handed players have missing salary values.")
print(f"In global, we see that {percentage_missing_sal_global:.2%} of the players have missing salary values.")
# Out:
# We see that 29.93% of the left-handed players have missing salary values.
# We see that 31.87% of the right-handed players have missing salary values.
# In global, we see that 31.30% of the players have missing salary values.

# %%
# We caluclate the percentage of more right handed peaoe than left handed people
percentage_right_handed = playerId_and_sal.loc["R", "playerID"] / playerId_and_sal["playerID"].sum()
print(f"We see that {percentage_right_handed:.2%} of the players are right handed.")

percentage_left_handed = playerId_and_sal.loc["L", "playerID"] / playerId_and_sal["playerID"].sum()
print(f"We see that {percentage_left_handed:.2%} of the players are left handed.")
# Out:
# We see that 70.75% of the players are right handed.
# We see that 29.25% of the players are left handed.

# %% [markdown]
# We see that only 30% percent of the pitchers are left handed thereforore we cannot really compare the two graphs like that. Indeed, sice the graph for the right handed pitcher is naturally "bigger" it is difficult to visually compare the two and be confident to say that they have the same distribution or not. Furthermore since the two are graphed on the same y label the graph for the left handed pitchers is more squashed and difficult to read.
#
# To counter that we can graph the density function and not the number of pitchers to have the same y values. We can also plot the log log graph for the CCDF to better see the differences in the small values in both graphs.

# %% [markdown]
# **2.3 —** Implement the solution proposed by yourself in the previous question.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize= (16,8), sharey = True, sharex = True)
ax1.hist(df[df.throws == "R"][["salary"]], cumulative=-1, histtype="step", log=True, bins = np.logspace(start=0, stop=np.log10(df["salary"].max())) )
ax2.hist(df[df.throws == "L"][["salary"]], cumulative=-1, histtype="step",log=True, bins = np.logspace(start=0, stop=np.log10(df["salary"].max())) )
ax1.set_title("CCDF histogram of salaries for right-handed pitchers with log log scale")
ax2.set_title("CCDF histogram of salaries for left-handed pitchers with log log scale")
# Out:
# Text(0.5, 1.0, 'CCDF histogram of salaries for left-handed pitchers with log log scale')

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize= (16,8), sharey = False, sharex = True)

ax1.hist(df[df.throws == "R"][["salary"]], bins=20, cumulative=-1, histtype="step", density=True)
ax2.hist(df[df.throws == "L"][["salary"]], bins=20, cumulative=-1, histtype="step", density=True)

ax1.set_title("CCDF histogram of salaries for right-handed pitchers with density")
ax1.set_xlabel("Salary")
ax1.set_ylabel("Number of pitchers / Tot number of pitchers")
ax1.ticklabel_format(style='plain') # This sets the scientific notation off


ax2.set_title("CCDF histogram of salaries for left-handed pitchers with density")
ax2.ticklabel_format(style='plain')
ax2.set_xlabel("Salary")
# Out:
# Text(0.5, 0, 'Salary')

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize= (16,8), sharey = True, sharex = True)

ax1.hist(df[df.throws == "R"][["salary"]], cumulative=-1, histtype="step", log=True, bins = np.logspace(start=0, stop=np.log10(df["salary"].max())), density=True)
ax2.hist(df[df.throws == "L"][["salary"]], cumulative=-1, histtype="step",log=True, bins = np.logspace(start=0, stop=np.log10(df["salary"].max())), density=True)

ax1.set_title("CCDF of salaries for R-handed pitchers with log-log scale and density")
ax1.set_xlabel("Salary (In log sacale)")
ax1.set_ylabel("Number of pitchers / Tot number of pitchers (In log sacale)")


ax2.set_title("CCDF of salaries for L-handed pitchers with log-log scale and density")
ax2.set_xlabel("Salary (In log sacale)")
# Out:
# Text(0.5, 0, 'Salary (In log sacale)')

# %% [markdown]
# **2.4 —** /Discuss:/ Considering this second version of the plot, describe what the plot shows with regard to the distribution of salaries from left- and right-handed pitchers.

# %% [markdown]
# The log-log plot without the density doesn't tell us much more than the first plot, since the y axis is still not similar it is hard to compare.
#
# In the density plot with normal scale we can see that the distribution is pretty much the same but it seams like the left handed pitchers tend to earn more and bigger "biggest salaries" than the right handed pitchers. Indeed, we kinda see that the tail of the power laws goes a bit further on the L-handed pitcher's graph, this is visible at the $15 000 000 mark and the $20 000 000 mark.
#
# This observation is confirmed in the density plot with the log-log scale where we clearely see that the proportion of left handed pitchers that earn between 17 and 25 millions dollars is bigger than the proportion of right handed pitcher that earn the same amount of money.

# %%
df[df.salary >= 17000000].groupby(by="throws")[["salary"]].count()
# Out:
#         salary
# throws
# L            5
# R            7

# %% [markdown]
# We can note that there is more right handed players than left handed players wich earn more than 17 millions dollars per year. But by looking at the density as we did before, you can conclude that a left handed player has more chances to win more than 17 millions dolloars per year than a right handed player.
#
# Why is that the case ? Is it beacause having good right and left handed player in your team is important, and as they is fewer left handed players playing baseball, there is fewer very good one and therfore they are more expensive (Supply and demand relasionship) ? Is it beaucause beeing left handed in baseball is easier, or gives an advantage, and therefore the left handed players are better than the right handed palyer ? Are left handed people intrinsically better than right handed people ? (Some of) Those questions can maybe be answered with a thurly analysis of the data...

# %% [markdown]
# **2.5—** Calculate the mean and the 95% confidence interval for the salary of left-handed and right-handed pitchers aggregating data across all years. Print the estimates. Additionally, present the estimates and the confidence intervals in a [point plot](https://seaborn.pydata.org/_images/pointplot_7_0.png). Calculate your confidence intervals using the standard error of the mean and ignoring missing values.

# %%
grouped_salary = df[["yearID", "throws", "salary"]].groupby(["yearID", "throws"])
grouped_salary.head()
# Out:
#      yearID throws      salary
# 0      1998      R         NaN
# 1      2000      L    200000.0
# 2      2007      L   3000000.0
# 3      2010      L         NaN
# 4      1992      L         NaN
# ..      ...    ...         ...
# 697    2010      L  20144707.0
# 705    2005      L    362500.0
# 721    1988      L         NaN
# 722    1988      L    465000.0
# 759    1991      L    110000.0
#
# [260 rows x 3 columns]

# %%
grouped_salary_mean = grouped_salary.mean().add_suffix('_mean')
grouped_salary_sem = grouped_salary.sem().add_suffix('_sem')

grouped_salary = pd.concat([grouped_salary_mean, grouped_salary_sem], axis=1)

grouped_salary["ci"] = 1.96 * grouped_salary["salary_sem"]
grouped_salary["upp_ci"] = grouped_salary["salary_mean"] + 1.96 * grouped_salary["salary_sem"]
grouped_salary["low_ci"] = grouped_salary["salary_mean"] - 1.96 * grouped_salary["salary_sem"]


grouped_salary.head(100)
# Out:
#                 salary_mean     salary_sem             ci        upp_ci  \
# yearID throws
# 1985   L       4.261049e+05   30152.374556   59098.654129  4.852036e+05
#        R       4.830556e+05   25670.366326   50313.918000  5.333695e+05
# 1986   L       3.525709e+05   31085.030107   60926.659010  4.134976e+05
#        R       4.036011e+05   24768.924631   48547.092276  4.521482e+05
# 1987   L       3.716056e+05   34078.901422   66794.646786  4.384002e+05
#        R       4.502739e+05   30136.833614   59068.193884  5.093421e+05
# 1988   L       4.358656e+05   39873.591483   78152.239306  5.140178e+05
#        R       4.174334e+05   28339.118997   55544.673234  4.729781e+05
# 1989   L       4.904536e+05   51210.893318  100373.350902  5.908270e+05
#        R       4.904632e+05   35445.043543   69472.285344  5.599355e+05
# 1990   L       4.928855e+05   43897.980416   86040.041615  5.789255e+05
#        R       4.835311e+05   31033.479910   60825.620624  5.443568e+05
# 1991   L       7.425432e+05   83469.991289  163601.182926  9.061444e+05
#        R       9.949598e+05   68422.594381  134108.284987  1.129068e+06
# 1992   L       1.095080e+06  110311.236930  216210.024383  1.311290e+06
#        R       1.093759e+06   80097.749923  156991.589850  1.250750e+06
# 1993   L       9.575292e+05  106711.862610  209155.250716  1.166684e+06
#        R       9.580979e+05   74585.047068  146186.692253  1.104285e+06
# 1994   L       9.978986e+05  120623.367498  236421.800297  1.234320e+06
#        R       9.512406e+05   76585.964517  150108.490454  1.101349e+06
# 1995   L       7.510972e+05   93856.834770  183959.396150  9.350566e+05
#        R       8.967446e+05   79681.907663  156176.539020  1.052921e+06
# 1996   L       8.606696e+05  110514.683960  216608.780562  1.077278e+06
#        R       7.990776e+05   69162.534629  135558.567872  9.346361e+05
# 1997   L       1.033917e+06  120465.882065  236113.128847  1.270030e+06
#        R       1.030745e+06   82697.708201  162087.508074  1.192832e+06
# 1998   L       1.085453e+06  123968.207069  242977.685856  1.328431e+06
#        R       1.181355e+06   84758.042982  166125.764244  1.347481e+06
# 1999   L       1.272792e+06  144485.753589  283192.077035  1.555984e+06
#        R       1.428778e+06  103529.301306  202917.430560  1.631696e+06
# 2000   L       1.744754e+06  221981.902218  435084.528348  2.179838e+06
#        R       1.839292e+06  132620.907028  259936.977776  2.099229e+06
# 2001   L       2.085521e+06  270332.539565  529851.777548  2.615372e+06
#        R       2.046541e+06  140235.660658  274861.894891  2.321403e+06
# 2002   L       2.137773e+06  251492.876099  492926.037154  2.630699e+06
#        R       2.170814e+06  150726.085216  295423.127023  2.466237e+06
# 2003   L       1.796229e+06  236755.800895  464041.369753  2.260270e+06
#        R       2.320194e+06  181287.356142  355323.218038  2.675517e+06
# 2004   L       1.715595e+06  238578.435856  467613.734278  2.183209e+06
#        R       2.261087e+06  176568.507226  346074.274162  2.607161e+06
# 2005   L       2.374102e+06  275810.417547  540588.418392  2.914691e+06
#        R       2.431714e+06  189005.961867  370451.685259  2.802166e+06
# 2006   L       2.477651e+06  298712.799942  585477.087887  3.063128e+06
#        R       2.565833e+06  181898.886472  356521.817486  2.922355e+06
# 2007   L       2.328954e+06  272212.440764  533536.383898  2.862491e+06
#        R       2.706853e+06  188945.807223  370333.782157  3.077186e+06
# 2008   L       3.015256e+06  385259.433943  755108.490529  3.770364e+06
#        R       2.744913e+06  196701.132270  385534.219249  3.130447e+06
# 2009   L       3.016850e+06  361881.256840  709287.263407  3.726138e+06
#        R       2.927930e+06  226083.288456  443123.245373  3.371053e+06
# 2010   L       3.302736e+06  421885.517420  826895.614143  4.129631e+06
#        R       3.122889e+06  233216.043464  457103.445189  3.579992e+06
#
#                      low_ci
# yearID throws
# 1985   L       3.670063e+05
#        R       4.327417e+05
# 1986   L       2.916442e+05
#        R       3.550540e+05
# 1987   L       3.048109e+05
#        R       3.912057e+05
# 1988   L       3.577133e+05
#        R       3.618888e+05
# 1989   L       3.900803e+05
#        R       4.209909e+05
# 1990   L       4.068455e+05
#        R       4.227055e+05
# 1991   L       5.789420e+05
#        R       8.608515e+05
# 1992   L       8.788704e+05
#        R       9.367670e+05
# 1993   L       7.483740e+05
#        R       8.119112e+05
# 1994   L       7.614768e+05
#        R       8.011321e+05
# 1995   L       5.671378e+05
#        R       7.405681e+05
# 1996   L       6.440609e+05
#        R       6.635190e+05
# 1997   L       7.978042e+05
#        R       8.686574e+05
# 1998   L       8.424751e+05
#        R       1.015229e+06
# 1999   L       9.896002e+05
#        R       1.225861e+06
# 2000   L       1.309669e+06
#        R       1.579355e+06
# 2001   L       1.555669e+06
#        R       1.771679e+06
# 2002   L       1.644846e+06
#        R       1.875390e+06
# 2003   L       1.332187e+06
#        R       1.964871e+06
# 2004   L       1.247982e+06
#        R       1.915013e+06
# 2005   L       1.833514e+06
#        R       2.061262e+06
# 2006   L       1.892174e+06
#        R       2.209311e+06
# 2007   L       1.795418e+06
#        R       2.336519e+06
# 2008   L       2.260147e+06
#        R       2.359379e+06
# 2009   L       2.307563e+06
#        R       2.484806e+06
# 2010   L       2.475840e+06
#        R       2.665785e+06

# %%
# I don't know if it is good to do it with sns and discuss that in the report !!
#sns.pointplot(data=grouped_salary[grouped_salary.index.get_level_values('yearID')<= 1985], x="yearID", y="salary_mean", hue="throws")
sns.set(rc={'figure.figsize':(14,9)})
sns.pointplot(data=df, x="yearID", y="salary", hue="throws", errorbar=("ci", 95), dodge=0.1, capsize=0.1)
# Out:
# <AxesSubplot:xlabel='yearID', ylabel='salary'>

# %% [markdown]
# **2.6 —** /Discuss:/ Can you tell whether the difference between the two distributions is statistically significant (at the .05 level of significance) from the image? Why?

# %% [markdown]
# We clearely see that every year (appart from 1991, 2003, 2004) both means are in the other's confidence interval. So the two distributions are not really statistically significant and we cannot really get a trend form this immage.

# %% [markdown]
# **2.7 —** Perform a t-test test comparing the salaries of left-handed and right-handed pitchers at the .05 level of significance. Consider data from all years. /Discuss:/ Who earns more?

# %% [markdown]
# ---
#
# Now, let's turn to analyzing performance. A commonly used metric to evaluate the skill of a pitcher is to look at the batting average of the pitcher’s opponents. According to [Wikipedia](https://en.wikipedia.org/wiki/Batting_average_against),
#
# > In baseball statistics, batting average against (denoted by BAA or AVG), also known as opponents' batting average (denoted by OBA), is a statistic that measures a pitcher's ability to prevent hits during official at bats. It can alternatively be described as the league's hitters' combined batting average against the pitcher.
#
# The intuition is clear: if you are a pitcher, you do not want the batter actually to hit the ball. Thus, if you are a good pitcher, the opponent batter should miss a lot against you! Conveniently, this is already calculated on a yearly basis in our data.
#
# ---

# %% [markdown]
# **2.8 —** Considering data from all years, calculate the mean opponents' batting average for left- and right-handed pitchers. Run a t-test test to determine if this difference is statistically significant at the .05 level of significance. **Consider only pitchers in the years during which they have played atleast 5 games.** /Discuss:/ According to this approach, who are the better pitchers? Left-handed or right-handed pitchers?

# %% [markdown]
# # Task 3 (18 pts)
#
# Before you report your results to Mr. Russo, you decide to run them by your favorite Applied Data Analysis' TA, Ms. Sakota. She seems skeptical! According to her, you should take into account the time variable!

# %% [markdown]
# **3.1 —** Repeat the analysis from tasks 2.7 and 2.8 considering only data from the year 2000. That is, use a t-test to determine the distribution of salaries (2.7) and opponents' batting average (2.8) for all data of the year 2000 only.

# %% [markdown]
# **3.2 —** Create a single plot with 14 inches of width and 4 inches of height. The plot should contain three panels:
# - Panel A: The percentage of left-handed pitchers per year;
# - Panel B: The average salary of all pitchers per year
# - Panel C: The average opponents' batting average of all pitchers per year.
#
# Additionally, print, for the year 2007:
# - the percentage of left-handed pitchers.
# - the average salary.
# - the average  opponents' batting average.

# %% [markdown]
# **3.3 —** Create a single plot with 10 inches of width and 4 inches of height. The plot should contain two panels:
# - Panel A: The average salary for left and right-handed pitchers per year, show 95% confidence intervals in your plot.
# - Panel B: The average opponents' batting average for left and right-handed pitchers across the years, show 95% confidence intervals in your plot.
#
#
# Additionally, print, for the year 1999:
# - the average salary of left-handed pitchers.
# - the average opponents' batting average of right-handed pitchers.

# %% [markdown]
# **3.4 —** /Discuss:/ Contrast the results obtained in Tasks 3.1 / 3.3 / 3.3 with the results obtained in Tasks 2.7 and 2.8. Are left-handed better than right-handed pitchers? Do they earn better salaries? Explain why the analysis might have reached different results.

# %% [markdown]
# **3.5 —** Before showing the final results to Mr. Russo, you pass them by Ms. Sakota once more. She looks happier now, but still looks a bit concerned. She asks you to perform a sanity check on the missing data for the period you are considering. Specifically, she is worried that there are significantly more missing salaries for left-handed pitchers or for right-handed pitchers.
#
# - Create a plot with 10 inches of width and 4 inches of height. The plot should depict the fraction of missing salary  salary for left and right-handed pitchers per year, show 95% confidence intervals in your plot.
# - Print the fraction of left-handed pitchers with salary data missing for the year 2002.
# - /Discuss:/ According to the plot, are there significantly more missing salaries for left-handed pitchers?

# %% [markdown]
# **3.6 –**  /Discuss:/ If 95% of the salaries of right-handed pitchers were missing and none for the left-handed pitchers, what problem could you envision could happen downstream when you analyzed the data?
